# %%
# !pip install pandas pyarrow

# %%
import pandas as pd

# %%
aed_locations= pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\aed_locations.parquet.gzip")
aed_locations
# Out:
#             id                         type                address  number  \
# 0         13.0                         None    Blvd. Fr. Roosevelt    24.0
# 1         70.0                         None        Ch. De Wégimont    76.0
# 2         71.0                         None  Place Saint - Lambert     NaN
# 3         72.0                         None          Rue du Doyard     NaN
# 4         73.0                         None     Fond Saint Servais     NaN
# ...        ...                          ...                    ...     ...
# 15222  16662.0  Appareil fixe-Vast apparaat     Nekkerspoel-Borcht    19.0
# 15223  16664.0  Appareil fixe-Vast apparaat          Nieuwe Dreef     17.0
# 15224  16665.0  Appareil fixe-Vast apparaat     Panterschipstraat    207.0
# 15225  16666.0  Appareil fixe-Vast apparaat    Albert Leemansplein    20.0
# 15226  16668.0  Appareil fixe-Vast apparaat        rue Saint-Donat    18.0
#
#        postal_code municipality           province  \
# ...

# %%
ambulance_locations = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\ambulance_locations.parquet.gzip")
ambulance_locations
# Out:
#                                        base  \
# 0               BA ANTW [Borgerhout] AMBUCE
# 1                  BA ANTW [Hoboken] AMBUCE
# 2    BA ANTW [Hof Ter Schelde] AC Antwerpen
# 3                  BA ANTW [Kaai 606] SIHWA
# 4     BA ANTW [Sint Elisabeth] AC Antwerpen
# ..                                      ...
# 274                  FX PDS SHUB Luxembourg
# 275                 HG UR HERS Andre Renard
# 276                HG UR LIEG CHR Citadelle
# 277      HG UR LIEG CHU Notre Dame Bruyeres
# 278     HULPVERLENINGSZONE ZUIDWEST LIMBURG
#
#                                       medical_resource   province  \
# 0                     ZW ANTWERPEN 7 (Team: AAANTW07A)  Antwerpen
# 1                     ZW ANTWERPEN 9 (Team: AAANTW09A)  Antwerpen
# 2                     ZW ANTWERPEN 3 (Team: AAANTW03A)  Antwerpen
# 3    ZW ANTWERPEN HAVEN 1 (Team: AAAPOR01A)_x000D_Z...  Antwerpen
# 4                     ZW ANTWERPEN 2 (Team: AAANTW02A)  Antwerpen
# ...

# %%
cad9 = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\cad9.parquet.gzip")
cad9
# Out:
#        province   Mission ID                 Service Name  \
# 0           VBR  21221520003             MV HVP VILV West
# 1           VBR  21221520004             MV HVP HALL West
# 2           VBR  21221520007             MV HVP VILV West
# 3           VBR  21221520007   HV UR VILV AZ Jan Portaels
# 4           VBR  21221520008  BB BRUX Hôpital Militair KA
# ...         ...          ...                          ...
# 289396      NAM  90221870001             BF SART BHN AMBU
# 289397      NAM  90221870002   MF PDS BRAL Brabant Wallon
# 289398      NAM  90221870003   MF PDS WAVR Brabant Wallon
# 289399      NAM  90221880001             BF SART BHN AMBU
# 289400      NAM  90222280001      MH PDS BEAU Hainaut Est
#
#         Latitude permanence  Longitude permanence Permanence short name  \
# 0                 50.925277              4.423057             AVVILV01A
# 1                 50.743200              4.241053             AVHALL02A
# ...

# %%
intervention_bxl = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\interventions_bxl.parquet.gzip")
intervention_bxl
# Out:
#          mission_id                          service_name  \
# 0       20222490011         FB PDS BRUX [PASI CitÈ] SIAMU
# 1       20222490011         FB PDS BRUX [PASI CitÈ] SIAMU
# 2       20222490012              HB UR BRUX CHU St Pierre
# 3       20222490015         FB PDS BRUX [PASI CitÈ] SIAMU
# 4       20222490019          FB PDS WOLL [PASI UCL] SIAMU
# ...             ...                                   ...
# 115642  20231510397         FB PDS BRUX [PASI CitÈ] SIAMU
# 115643  20231510397         FB PDS BRUX [PASI CitÈ] SIAMU
# 115644  20231510399   FB PDS ANDE [PASI Anderlecht] SIAMU
# 115645  20231510399   FB PDS ANDE [PASI Anderlecht] SIAMU
# 115646  20231510400  FB PDS BRUX [Caserne HÈliport] SIAMU
#
#         postalcode_permanence                          cityname_permanence  \
# 0                        1000                            Brussel (Brussel)
# 1                        1000                            Brussel (Brussel)
# ...

# %%
intervention_bxl2=pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\interventions_bxl2.parquet.gzip")
intervention_bxl2
# Out:
#         Mission ID                T0  \
# 0      20221520003  01JUN22:00:02:45
# 1      20221520005  01JUN22:00:04:58
# 2      20221520006  01JUN22:00:07:43
# 3      20221520006  01JUN22:00:07:43
# 4      20221520007  01JUN22:00:09:18
# ...            ...               ...
# 38615  20222495211  06SEP22:14:02:31
# 38616  20222495213  06SEP22:14:11:22
# 38617  20222495214  06SEP22:14:11:47
# 38618  20222495214  06SEP22:14:11:47
# 38619  20222495215  06SEP22:14:13:51
#
#                                    Cityname Intervention  \
# 0                           1030 schaerbeek (schaerbeek)
# 1                           1030 schaerbeek (schaerbeek)
# 2                           1081 koekelberg (koekelberg)
# 3                           1081 koekelberg (koekelberg)
# 4                           1030 schaerbeek (schaerbeek)
# ...                                                  ...
# 38615  1210 saint-josse-ten-noode (saint-josse-ten-no...
# ...

# %%
interventions1 = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\interventions1.parquet")
interventions1
# Out:
#          Mission ID                 Service Name  PostalCode permanence  \
# 0       10221520001     HA UR MECH AZ St Maarten                 2800.0
# 1       10221520002               BA KAPE AMBUCE                 2950.0
# 2       10221520002       HA UR ANTW Stuivenberg                 2060.0
# 3       10221520004  BA ANTW [Borgerhout] AMBUCE                 2140.0
# 4       10221520005               BA WIJN AMBUCE                 2110.0
# ...             ...                          ...                    ...
# 200622  50221920082      FH PDS BEAU Hainaut Est                 6500.0
# 200623  50221920083            BH LOUV AS Grande                 7110.0
# 200624  50221920084  BH GERP SAPG Poste Loverval                 6280.0
# 200625  50221920085   FH PDS BINC Hainaut Centre                 7130.0
# 200626  50221920085        HH UR LOUV CHU Tivoli                 7100.0
#
#                         CityName permanence       StreetName permanence  \
# ...

# %%
interventions2 = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\interventions2.parquet",engine="pyarrow")
interventions2
# Out:
#          Mission ID                       Service Name  PostalCode permanence  \
# 0       50221920087       FH PDS COMI Wallonie Picarde                 7784.0
# 1       50221920088       FH PDS TOUR Wallonie Picarde                 7500.0
# 2       50221920089         FH PDS LOUV Hainaut Centre                 7100.0
# 3       50221920090  FW HVP HEUV [Nieuwkerke] Westhoek                 8950.0
# 4       50221920092                BH SGHI Croix Rouge                 7331.0
# ...             ...                                ...                    ...
# 200622  60230050005                BG BLEG Croix Rouge                 4671.0
# 200623  60230050006                      BG AWAN PARAM                 4340.0
# 200624  60230050006           HG UR LIEG CHC Montlegia                 4000.0
# 200625  60230050007                BG LIEG Croix Rouge                 4000.0
# 200626  60230050008                BG OUPE Croix Rouge                 4680.0
#
# ...

# %%
interventions3 = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\interventions3.parquet")
interventions3
# Out:
#          Mission ID                        Service Name  \
# 0       60230050009                 BG LIEG Croix Rouge
# 1       60230050010  FG PDS PEPI Vesdre Ho√´gne Plateau
# 2       60230050012                    BG LIEG Courtois
# 3       60230050013             FG PDS ANS_ Li√®ge IILE
# 4       60230050014             FG PDS FLEM Li√®ge IILE
# ...             ...                                 ...
# 200622  90231510181                    FN PDS NAMU NAGE
# 200623  90231510182                 FN PDS DINA DINAPHI
# 200624  90231510183          FF PDS TUBI Brabant Wallon
# 200625  90231510184                    FN PDS NAMU NAGE
# 200626  90231510185                 BN NAMU Croix Rouge
#
#         PostalCode permanence          CityName permanence  \
# 0                      4000.0              Li√®ge (Li√®ge)
# 1                      4860.0        Pepinster (Pepinster)
# 2                      4030.0          Li√®ge (Grivegn√©e)
# ...

# %%
mug_locations = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\mug_locations.parquet.gzip")
mug_locations
# Out:
#     hospital_id  mug_id  campus_id                      name_hospital  \
# 0             9  102000       6230  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 1            99  102000       2020                  GZA- ZIEKENHUIZEN
# 2           682  102000       1210                          AZ MONICA
# 3             9  103000       2000  ZIEKENHUISNETWERK ANTWERPEN (ZNA)
# 4            99  103000       1290                  GZA- ZIEKENHUIZEN
# ..          ...     ...        ...                                ...
# 89           20  808000       3010        CHR VERVIERS - EAST BELGIUM
# 90          168  901000       3720                           VIVALIA
# 91          246  902000       3690                           VIVALIA
# 92          168  903000       3240                           VIVALIA
# 93          164  904000       3230                           VIVALIA
#
#              name_campus           address_campus  postal_code  \
# 0              ZNA CADIX         KEMPENSTRAAT 100         2030
# ...

# %%
pit_location = pd.read_parquet(r"C:\Users\rafor\OneDrive\Documents\GitHub\datathon\Data\pit_locations.parquet.gzip")
pit_location
# Out:
#                                                unit  \
# 0                  100001: PIT Rumst, AZ Rivierland
# 1                102001: PIT Deinze, St Vincentius
# 2                           102101: PIT Stuivenberg
# 3                     110001: PIT Lier, Heilig Hart
# 4                113001: PIT HEILIG HART ZIEKENHUIS
# 5                               200001: PIT LOKEREN
# 6                             210001: PIT ASSE, OLV
# 7          301001: PIT ST Jan (Associatie St Lucas)
# 8   301001: PIT St Lucas Brugge (associatie St Jan)
# 9                          303001: PIT Blankenberge
# 10                        404001: PIT Genk, St Jan
# 11                501001: PIT Leuven, Gasthuisberg
# 12                   520001: PIT Ixelles, Iris Sud
# 13                  523001: PIT St Pierre Bruxelles
# 14                           526001: PIT UZ BRUSSEL
# 15                                600001: PIT GILLY
# 16                                 601001: PIT MONS
# ...
